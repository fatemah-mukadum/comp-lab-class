# %%
# install gromacs library and import it
# %pip install gromacs
import gromacs
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# load mdtraj
import mdtraj as md
# load gro file
traj = md.load('Inputs/ala300.trr', top='Inputs/ala300.gro')

# %%
# compute phi and psi dihedral angle from trajectory
#phi_psi = md.compute_dihedrals(traj, np.array([[5, 6, 8, 14]]))
# compute psi angle from trajectory
psi = md.compute_psi(traj)
# compute phi angle from trajectory
phi = md.compute_phi(traj)
print(phi)
# compute phi and psi dihedral angle from trajectory
#phi_psi = md.compute_dihedrals(traj, np.array([[5, 6, 8, 14], [6, 8, 14, 15]]))
# Out:
# (array([[ 4,  6,  8, 14]]), array([[-2.8562374 ],
#        [-2.9124331 ],
#        [-2.5155468 ],
#        [-2.220027  ],
#        [-2.6933737 ],
#        [-1.3397322 ],
#        [-2.084867  ],
#        [-2.7597775 ],
#        [-2.6543918 ],
#        [-1.7602824 ],
#        [-1.3209034 ],
#        [-1.1307694 ],
#        [-1.9595523 ],
#        [-1.3399085 ],
#        [-1.4263965 ],
#        [-1.285493  ],
#        [-1.4264262 ],
#        [-1.267048  ],
#        [-1.3591855 ],
#        [-1.3206505 ],
#        [-1.7536222 ],
#        [-1.6859808 ],
#        [-1.4245757 ],
#        [-1.3357004 ],
#        [-1.3718367 ],
#        [-1.1505504 ],
#        [-1.2886373 ],
#        [-1.508124  ],
#        [-1.2163355 ],
#        [-1.5399193 ],
#        [-1.3362073 ],
#        [-1.1305485 ],
#        [-1.3924421 ],
#        [-1.6878406 ],
#        [-1.4145097 ],
#        [-1.5356296 ],
#        [-1.5089834 ],
#        [-1.1699743 ],
#        [-1.2419877 ],
#        [-1.4136748 ],
# ...

# %%
# plot phi vs time 
plt.plot(traj.time, phi[1])
plt.xlabel('Time (ps)')
plt.ylabel('Phi (rad)')
plt.title('Phi vs Time')
plt.show()
# use arial font and make bigger
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.savefig("Phi-Time.png", format="png", bbox_inches="tight")

# %%
# plot psi vs time
plt.plot(traj.time, psi[1])
plt.xlabel('Time (ps)')
plt.ylabel('Psi (rad)')
plt.title('Psi vs Time')
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.savefig("PhivsTime.png", format="png", bbox_inches="tight")

# %%
# compute a 2d histogram of phi and psi angles
H, xedges, yedges = np.histogram2d(phi[1].flatten(), psi[1].flatten(), bins=50)
# plot the -log of the histogram
plt.imshow(-np.log(H.T), extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]], aspect='auto', origin='lower')
# add labeled colorbar
plt.colorbar(label='-log(Probability)')
# add axis labels
plt.xlabel('Phi (rad)')
plt.ylabel('Psi (rad)')
plt.title('Phi-Psi Probability')
# use arial font and make bigger
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.savefig("Phi-Psi-Hist.png", format="png", bbox_inches="tight")
# Out:
# /tmp/ipykernel_1955608/389703467.py:4: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(-np.log(H.T), extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]], aspect='auto', origin='lower')
