# %%
import mdtraj as md
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# plot potential energy vs time from outputs 
npt = np.loadtxt('../Outputs/NPT-1.ener', skiprows=1)
nvt = np.loadtxt('../Outputs/NVT-1.ener', skiprows=1)

# %%
# plot potential energy vs time from outputs
plt.plot(npt[:,1], npt[:,4], label='NPT')
plt.plot(nvt[:,1], nvt[:,4], label='NVT')
# add labels 
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u)')
plt.title('Potential Energy vs Time')
plt.legend()
plt.savefig('nvtnpt.png', dpi=400)

# %%
qm_mm = np.loadtxt('../Outputs/monitor/MONITOR-1.ener', skiprows=1)
plt.plot(qm_mm[:,1], qm_mm[:,4], label='QM/MM')
plt.xlabel('Time (fs)')
plt.ylabel('Potential Energy (a.u)')
plt.title('Potential Energy vs Time')
plt.legend()
plt.savefig('qm_mm.png', dpi=400)

# %%
rxn_dat = np.loadtxt('../Outputs/monitor/MONITOR-COLVAR.metadynLog')
metad_1 = np.loadtxt('../Outputs/metad1_initmonitor/METADYN-COLVAR.metadynLog')
metad_2 = np.loadtxt('../Outputs/metad1_initmonitor_freqhills/METADYN-COLVAR.metadynLog')
# plot first column vs second 
plt.plot(rxn_dat[:,0],rxn_dat[:,1], label='QM/MM')
plt.plot(metad_1[:,0],metad_1[:,1],  label='FREQ 100|HEIGHT 1.5|WIDTH 0.5')
plt.plot(metad_2[:,0],metad_2[:,1],  label='FREQ 20|HEIGHT 1.5|WIDTH 0.5')
plt.xlabel('Time (fs)')
plt.ylabel('Rxn Coord Distance: \n (Atom 5663-Atom 5675) - (Atom 5670- Atom 5671)', fontsize=10)
plt.title('Reaction Coordinate vs Time')
plt.savefig('rxn_coord.png', dpi=400)
plt.legend()
